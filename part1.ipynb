# %% [markdown]
# # MATH60005/70005: Optimisation Coursework Part I
# ## Gradient-Enhanced Polynomial Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import pandas as pd

# Set plotting style
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
print("\n--- Part I.a): Standard Polynomial Regression ---\n")

# Load training and validation data
training_data_Ia = np.loadtxt('datasets/trainingIa.dat')
validation_data_Ia = np.loadtxt('datasets/validationIa.dat')

# Extract x and V(x) from training data
x_train = training_data_Ia[:, 0]
V_train = training_data_Ia[:, 1]
m_train = len(x_train)

# Extract x and V(x) from validation data
x_val = validation_data_Ia[:, 0]
V_val = validation_data_Ia[:, 1]
m_val = len(x_val)

print(f"Training samples: {m_train}")
print(f"Validation samples: {m_val}")
# Out:
# --- Part I.a): Standard Polynomial Regression ---
#
# Training samples: 50
# Validation samples: 100
